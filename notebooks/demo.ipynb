# %% [markdown]
# # GSAT-6A Autonomous Failure Analysis via Aethelix
#
# This interactive demo maps the T+36 second anomaly identification utilizing Markov Bayesian updates natively against physical ISRO GSAT-6A payloads.

# %%
import sys
import os
sys.path.append(os.path.abspath('..'))

from examples.gsat6a.mission_analysis import GSAT6AMissionAnalysis
analyzer = GSAT6AMissionAnalysis()
analyzer.analyze_and_visualize()

print("E2E Trace Validation Successful.")
